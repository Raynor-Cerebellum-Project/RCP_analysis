# %% [markdown]
# # Run Batch Scripts

# %%
"""
Run scripts in order. Comment out ones you don't want to run.
"""

import subprocess
from pathlib import Path

BATCH_SCRIPTS = [
    # "align_dlc_two_cams_to_br.py",
    # "align_VOG_to_br.py",
    # "NPRW_Intan_analysis_threshold.py",
    # "compute_br_to_intan_shifts.py",
    # "UA_BR_analysis_threshold.py",
    "make_aligned_npz_and_mat.py",
    "extract_peri_IR_and_concat_baseline.py",
    "extract_peri_stim.py",
    "generate_stim_summary.py",
    "plot_complete_shaded_BT.py",
    "quantify_stim_kinematics.py",
    "RSA_calculation.py",
]

def run_scripts(base_dir: Path):
    for batch_script in BATCH_SCRIPTS:
        script_path = base_dir / batch_script
        print(f"\n[INFO] Running {script_path} ...\n")
        try:
            subprocess.run(
                ["python", str(script_path)],
                check=True
            )
        except subprocess.CalledProcessError as e:
            print(f"[ERROR] Script {batch_script} failed with exit code {e.returncode}")
            break

BASE = Path().resolve().parents[0]
BATCH_SCRIPTS_FOLDER = BASE / "batch_scripts"
run_scripts(BATCH_SCRIPTS_FOLDER)
# Out:
# [INFO] Running /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Bryan/RCP_analysis/batch_scripts/UA_BR_analysis_threshold.py ...
#
# Found session folders: 26
# === Session: NRR_RW011_002 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_002__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 002 -> Intan session 'NRR_RW011_251203_135743'
# [WARN] no stim found, skipping artifact removal.
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 57/57 [01:02<00:00,  1.09s/it]
# [NRR_RW011_002] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_002__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 40.12it/s]
# [INFO] Segments of recording: 1, Average noise level: 6.094813346862793
# detect peaks using by_channel_torch (workers: 8 processes): 100%|██████████| 57/57 [00:16<00:00,  3.51it/s]
# Unique touchscreen states: [0 1 2]
# [NRR_RW011_002] saved rate matrix-> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/rates__NRR_RW011_002__bin20ms_sigma20ms.npz
# === Session: NRR_RW011_003 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_003__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 003 -> Intan session 'NRR_RW011_251203_140253'
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 49/49 [00:54<00:00,  1.11s/it]
# [NRR_RW011_003] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_003__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 41.33it/s]
# [INFO] Segments of recording: 1, Average noise level: 1.1338865756988525
# detect peaks using by_channel_torch (workers: 8 processes): 100%|██████████| 49/49 [00:18<00:00,  2.72it/s]
# Unique touchscreen states: [0 1 2]
# [NRR_RW011_003] saved rate matrix-> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/rates__NRR_RW011_003__bin20ms_sigma20ms.npz
# === Session: NRR_RW011_004 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_004__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 004 -> Intan session 'NRR_RW011_251203_140957'
# [WARN] no stim found, skipping artifact removal.
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 46/46 [00:51<00:00,  1.11s/it]
# [NRR_RW011_004] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_004__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 50.91it/s]
# [INFO] Segments of recording: 1, Average noise level: 6.1066131591796875
# detect peaks using by_channel_torch (workers: 8 processes): 100%|██████████| 46/46 [00:18<00:00,  2.54it/s]
# Unique touchscreen states: [0 1 2]
# [NRR_RW011_004] saved rate matrix-> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/rates__NRR_RW011_004__bin20ms_sigma20ms.npz
# === Session: NRR_RW011_005 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_005__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 005 -> Intan session 'NRR_RW011_251203_141346'
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 30/30 [00:29<00:00,  1.01it/s]
# [NRR_RW011_005] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_005__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 40.27it/s]
# [INFO] Segments of recording: 1, Average noise level: 5.5650434494018555
# detect peaks using by_channel_torch (workers: 8 processes): 100%|██████████| 30/30 [00:06<00:00,  4.29it/s]
# Unique touchscreen states: [0 1 2]
# [NRR_RW011_005] saved rate matrix-> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/rates__NRR_RW011_005__bin20ms_sigma20ms.npz
# === Session: NRR_RW011_006 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_006__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 006 -> Intan session 'NRR_RW011_251203_141954'
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 44/44 [00:38<00:00,  1.13it/s]
# [NRR_RW011_006] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_006__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 37.79it/s]
# [INFO] Segments of recording: 1, Average noise level: 6.019524574279785
# detect peaks using by_channel_torch (workers: 8 processes): 100%|██████████| 44/44 [00:12<00:00,  3.55it/s]
# Unique touchscreen states: [0 1 2]
# [NRR_RW011_006] saved rate matrix-> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/rates__NRR_RW011_006__bin20ms_sigma20ms.npz
# === Session: NRR_RW011_007 ===
# [AUX] prepared ns5 aux (channels [134, 138])
# [AUX] ns2 signals: vog_sig=hhpos(id 131), vog_sync=vog_sync(id 135), touchscreen_sig=touchscreen_syn(id 142), hr_sig=heart_rate(id 136)
# [AUX] prepared ns2 digi (n_channels=12)
# [AUX] saved combined BR aux streams to /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/aux_data/UA/NRR_RW011_007__BR_aux_data.npz
# [MAP] UA port from metadata: 'A'
# [MAP] renamed 128/128 rows with UA mapping ('UAe###_NSP###') using port 'A'.
# SMA: 30 | Dorsal premotor: 32 | M1 inferior: 31 | M1 superior: 35
# [map] BR 007 -> Intan session 'NRR_RW011_251203_142450'
# write_binary_recording
# engine=process - n_jobs=8 - samples_per_chunk=120,000 - chunk_memory=29.30 MiB - total_memory=234.38 MiB - chunk_duration=4.00s
# write_binary_recording (workers: 8 processes): 100%|██████████| 49/49 [00:42<00:00,  1.15it/s]
# [NRR_RW011_007] (ns6) saved preprocessed -> /home/bryan/mnt/cullen/Current Project Databases - NHP/2025 Cerebellum prosthesis/Nike/20251203_NRR_RW011/results/checkpoints/UA/pp__NRR_RW011_007__NS6
# noise_level (workers: 8 processes): 100%|██████████| 20/20 [00:00<00:00, 40.55it/s]
# [INFO] Segments of recording: 1, Average noise level: 5.2229156494140625
